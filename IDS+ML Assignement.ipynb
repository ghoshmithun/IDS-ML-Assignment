# %% [markdown]
# # Problem: Predictive loan model for an applicant

# %% [markdown]
# ## Objective:
#
# Predict the risk of a loan being default based on the past loan data, for a given loan applicant
#
# Dataset:
#  https://drive.google.com/drive/folders/1XCKR-Gdw9yziWWW6TVvx5wvArFkP96PP
#
#  Dataset will be provided in parts
#
# Prep work required:
#
# Data for 3 quarters will be provided to the students, with a select subset of features. This will be used for prep work and initial baselining.
#
#  Identification of the performance parameters to be improved, for the given problem statement
#
#  Baseline performance figures for 5 different ML classifiers, after minimal data pre-processing, Baseline figures must include (i) accuracy (ii) classification report (iii) confusion matrix (iv) ROC-AUC and AUPRC scores. One of the classifiers must be ANN.
#
#  Observations from exploratory analysis of the dataset
#
#  Outline of feature engineering techniques that may be used to improve the classifier
# performance

# %% [markdown]
# # Performance
#
# Session 1:
#
# The complete dataset (with data for 2 more years and all features) will be provided.
#  Shortlist 3 best performing classifiers, from the prep work
#  Apply relevant feature engineering techniques on the dataset provided
#  Compare the performance of the 3 classifiers with the baseline performance figured obtained
# during prep-work
#  Note down the features that figure high in feature ranking
#
# Session 2:
#  Apply ensemble techniques to observe their impact on the performance of the classifiers
#
# Session 3:
#  Group presentation

# %% [markdown]
# # DataSet Description:

# %%
import os
import pandas as pd
def read_csv_data(dir_name):
    '''
    Arg: Directory Name
    Return: List of CSV files from a directory'''
    list_of_files=os.listdir(dir_name)
    return [file for file in list_of_files if file.endswith(".csv")]

def read_list_csv_to_pandas(list_of_csv_files):
    '''
    Arg: List of csv files name
    Return: Pandas dataframe with all file
    Assumption: ALl the files have same format'''
    pandas_list=[]
    for file in list_of_csv_files:
        pandas_list.append(pd.read_csv(os.path.join(utils['raw_data_path'],file),skiprows=1))
    merged_file=pd.concat(pandas_list)
    return merged_file

# %%
DATA_PATH='/Users/mghosh2/Downloads/loan_data/'

utils={
    'raw_data_path':DATA_PATH
}

# %%
list_of_files=read_csv_data(utils['raw_data_path'])
list_of_files
# Out:
# ['LoanStats_securev1_2017Q1.csv',
#  'LoanStats_securev1_2017Q2.csv',
#  'LoanStats_securev1_2017Q3.csv']

# %%
# !head -n 5 /Users/mghosh2/Downloads/loan_data/LoanStats_securev1_2017Q1.csv
## It looks like first row is not useful
# Out:
# Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# "id","member_id","loan_amnt","funded_amnt","funded_amnt_inv","term","int_rate","installment","grade","sub_grade","emp_title","emp_length","home_ownership","annual_inc","verification_status","issue_d","loan_status","pymnt_plan","url","desc","purpose","title","zip_code","addr_state","dti","delinq_2yrs","earliest_cr_line","fico_range_low","fico_range_high","inq_last_6mths","mths_since_last_delinq","mths_since_last_record","open_acc","pub_rec","revol_bal","revol_util","total_acc","initial_list_status","out_prncp","out_prncp_inv","total_pymnt","total_pymnt_inv","total_rec_prncp","total_rec_int","total_rec_late_fee","recoveries","collection_recovery_fee","last_pymnt_d","last_pymnt_amnt","next_pymnt_d","last_credit_pull_d","last_fico_range_high","last_fico_range_low","collections_12_mths_ex_med","mths_since_last_major_derog","policy_code","application_type","annual_inc_joint","dti_joint","verification_status_joint","acc_now_delinq","tot_coll_amt","tot_cur_bal","open_acc_6m","open_act_il","open_il_12m","open_il_24m","mths_since_rcnt_il","total_bal_il","il_util","open_rv_12m","open_rv_24m","max_bal_bc","all_util","total_rev_hi_lim","inq_fi","total_cu_tl","inq_last_12m","acc_open_past_24mths","avg_cur_bal","bc_open_to_buy","bc_util","chargeoff_within_12_mths","delinq_amnt","mo_sin_old_il_acct","mo_sin_old_rev_tl_op","mo_sin_rcnt_rev_tl_op","mo_sin_rcnt_tl","mort_acc","mths_since_recent_bc","mths_since_recent_bc_dlq","mths_since_recent_inq","mths_since_recent_revol_delinq","num_accts_ever_120_pd","num_actv_bc_tl","num_actv_rev_tl","num_bc_sats","num_bc_tl","num_il_tl","num_op_rev_tl","num_rev_accts","num_rev_tl_bal_gt_0","num_sats","num_tl_120dpd_2m","num_tl_30dpd","num_tl_90g_dpd_24m","num_tl_op_past_12m","pct_tl_nvr_dlq","percent_bc_gt_75","pub_rec_bankruptcies","tax_liens","tot_hi_cred_lim","total_bal_ex_mort","total_bc_limit","total_il_high_credit_limit","revol_bal_joint","sec_app_fico_range_low","sec_app_fico_range_high","sec_app_earliest_cr_line","sec_app_inq_last_6mths","sec_app_mort_acc","sec_app_open_acc","sec_app_revol_util","sec_app_open_act_il","sec_app_num_rev_accts","sec_app_chargeoff_within_12_mths","sec_app_collections_12_mths_ex_med","sec_app_mths_since_last_major_derog","hardship_flag","hardship_type","hardship_reason","hardship_status","deferral_term","hardship_amount","hardship_start_date","hardship_end_date","payment_plan_start_date","hardship_length","hardship_dpd","hardship_loan_status","orig_projected_additional_accrued_interest","hardship_payoff_balance_amount","hardship_last_payment_amount","disbursement_method","debt_settlement_flag","debt_settlement_flag_date","settlement_status","settlement_date","settlement_amount","settlement_percentage","settlement_term"
# "104046719","","14000","14000","14000"," 36 months"," 15.99%","492.13","C","C5","Project Leader","10+ years","MORTGAGE","82000","Source Verified","Mar-2017","Current","n","https://lendingclub.com/browse/loanDetail.action?loan_id=104046719","","credit_card","Credit card refinancing","672xx","KS","31.07","0","May-1996","725","729","0","","","18","0","69578","63.2%","31","w","11438.26","11438.26","3912.17","3912.17","2561.74","1350.43","0.0","0.0","0.0","Dec-2017","492.13","Jan-2018","Dec-2017","714","710","0","","1","Individual","","","","0","0","202617","0","3","0","1","22","34430","57","0","2","13686","61","110037","0","9","0","3","11257","29762","63.4","0","0","140","250","13","13","6","13","","13","","0","7","9","8","13","4","14","21","9","18","0","0","0","0","100","25","0","0","286204","104008","81400","60167","","","","","","","","","","","","","","N","","","","","","","","","","","","","","","Cash","N","","","","","",""
# "104048967","","5000","5000","5000"," 36 months"," 25.49%","200.1","E","E4","Pilot","10+ years","MORTGAGE","215000","Source Verified","Mar-2017","Current","n","https://lendingclub.com/browse/loanDetail.action?loan_id=104048967","","debt_consolidation","Debt consolidation","067xx","CT","6.06","0","Jan-2004","765","769","4","","","11","0","8678","18.8%","16","f","4190.59","4190.59","1586.64","1586.64","809.41","777.23","0.0","0.0","0.0","Dec-2017","200.1","Jan-2018","Dec-2017","779","775","0","","1","Individual","","","","0","0","44754","1","3","2","4","7","35832","68","2","2","8659","27","46200","2","0","6","6","4069","37522","18.8","0","0","83","87","5","5","0","5","","0","","0","2","2","7","8","7","7","8","2","11","0","0","0","4","100","0","0","0","100763","44754","46200","49814","","","","","","","","","","","","","","N","","","","","","","","","","","","","","","Cash","N","","","","","",""
# "104028593","","4600","4600","4600"," 36 months"," 11.39%","151.45","B","B3","cable technician","4 years","RENT","44470","Not Verified","Mar-2017","Current","n","https://lendingclub.com/browse/loanDetail.action?loan_id=104028593","","credit_card","Credit card refinancing","066xx","CT","13.43","0","Dec-2003","770","774","1","","","7","0","5400","19.1%","11","w","3708.50","3708.50","1205.78","1205.78","891.50","314.28","0.0","0.0","0.0","Dec-2017","151.45","Jan-2018","Dec-2017","769","765","0","","1","Individual","","","","0","0","9625","1","1","0","1","22","4225","36","2","4","4670","24","28300","0","0","1","5","1375","9610","33.7","0","0","77","159","1","1","0","7","","1","","0","2","3","3","4","2","6","9","3","7","0","0","0","2","100","0","0","0","40000","9625","14500","11700","","","","","","","","","","","","","","N","","","","","","","","","","","","","","","Cash","N","","","","","",""

# %%
data_raw = read_list_csv_to_pandas(list_of_files)
data_raw.head()
# Out:
# /Users/mghosh2/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3209: DtypeWarning: Columns (0,118,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /Users/mghosh2/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3209: DtypeWarning: Columns (0,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
# /Users/mghosh2/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3209: DtypeWarning: Columns (0,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  104046719        NaN    14000.0      14000.0          14000.0   36 months
# 1  104048967        NaN     5000.0       5000.0           5000.0   36 months
# 2  104028593        NaN     4600.0       4600.0           4600.0   36 months
# 3  104046702        NaN    14000.0      14000.0          14000.0   60 months
# 4  104280113        NaN    15000.0      15000.0          15000.0   36 months
#
#   int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0   15.99%       492.13     C        C5  ...                            NaN
# 1   25.49%       200.10     E        E4  ...                            NaN
# 2   11.39%       151.45     B        B3  ...                            NaN
# 3   12.74%       316.69     C        C1  ...                            NaN
# 4    5.32%       451.73     A        A1  ...                            NaN
#
#   hardship_last_payment_amount disbursement_method  debt_settlement_flag  \
# 0                          NaN                Cash                     N
# 1                          NaN                Cash                     N
# 2                          NaN                Cash                     N
# 3                          NaN                Cash                     N
# 4                          NaN                Cash                     N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#   settlement_amount settlement_percentage  settlement_term
# 0               NaN                   NaN              NaN
# 1               NaN                   NaN              NaN
# 2               NaN                   NaN              NaN
# 3               NaN                   NaN              NaN
# 4               NaN                   NaN              NaN
#
# [5 rows x 151 columns]

# %%
", ".join(list(data_raw.columns))
# Out:
# 'id, member_id, loan_amnt, funded_amnt, funded_amnt_inv, term, int_rate, installment, grade, sub_grade, emp_title, emp_length, home_ownership, annual_inc, verification_status, issue_d, loan_status, pymnt_plan, url, desc, purpose, title, zip_code, addr_state, dti, delinq_2yrs, earliest_cr_line, fico_range_low, fico_range_high, inq_last_6mths, mths_since_last_delinq, mths_since_last_record, open_acc, pub_rec, revol_bal, revol_util, total_acc, initial_list_status, out_prncp, out_prncp_inv, total_pymnt, total_pymnt_inv, total_rec_prncp, total_rec_int, total_rec_late_fee, recoveries, collection_recovery_fee, last_pymnt_d, last_pymnt_amnt, next_pymnt_d, last_credit_pull_d, last_fico_range_high, last_fico_range_low, collections_12_mths_ex_med, mths_since_last_major_derog, policy_code, application_type, annual_inc_joint, dti_joint, verification_status_joint, acc_now_delinq, tot_coll_amt, tot_cur_bal, open_acc_6m, open_act_il, open_il_12m, open_il_24m, mths_since_rcnt_il, total_bal_il, il_util, open_rv_12m, open_rv_24m, max_bal_bc, all_util, total_rev_hi_lim, inq_fi, total_cu_tl, inq_last_12m, acc_open_past_24mths, avg_cur_bal, bc_open_to_buy, bc_util, chargeoff_within_12_mths, delinq_amnt, mo_sin_old_il_acct, mo_sin_old_rev_tl_op, mo_sin_rcnt_rev_tl_op, mo_sin_rcnt_tl, mort_acc, mths_since_recent_bc, mths_since_recent_bc_dlq, mths_since_recent_inq, mths_since_recent_revol_delinq, num_accts_ever_120_pd, num_actv_bc_tl, num_actv_rev_tl, num_bc_sats, num_bc_tl, num_il_tl, num_op_rev_tl, num_rev_accts, num_rev_tl_bal_gt_0, num_sats, num_tl_120dpd_2m, num_tl_30dpd, num_tl_90g_dpd_24m, num_tl_op_past_12m, pct_tl_nvr_dlq, percent_bc_gt_75, pub_rec_bankruptcies, tax_liens, tot_hi_cred_lim, total_bal_ex_mort, total_bc_limit, total_il_high_credit_limit, revol_bal_joint, sec_app_fico_range_low, sec_app_fico_range_high, sec_app_earliest_cr_line, sec_app_inq_last_6mths, sec_app_mort_acc, sec_app_open_acc, sec_app_revol_util, sec_app_open_act_il, sec_app_num_rev_accts, sec_app_chargeoff_within_12_mths, sec_app_collections_12_mths_ex_med, sec_app_mths_since_last_major_derog, hardship_flag, hardship_type, hardship_reason, hardship_status, deferral_term, hardship_amount, hardship_start_date, hardship_end_date, payment_plan_start_date, hardship_length, hardship_dpd, hardship_loan_status, orig_projected_additional_accrued_interest, hardship_payoff_balance_amount, hardship_last_payment_amount, disbursement_method, debt_settlement_flag, debt_settlement_flag_date, settlement_status, settlement_date, settlement_amount, settlement_percentage, settlement_term'

# %%
len(list(data_raw.columns))
# Out:
# 151

# %%
data_raw['loan_status'].value_counts()
# Out:
# Current               285047
# Fully Paid             27576
# Late (31-120 days)      5044
# Charged Off             3036
# In Grace Period         2661
# Late (16-30 days)       1564
# Default                    3
# Name: loan_status, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
from scipy import stats

#To plot figs on jupyter
# %matplotlib inline
# figure size in inches
rcParams['figure.figsize'] = 14,6

# %%
def resumetable(df):
    print(f"Dataset Shape: {df.shape}")
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values 
    summary['Non_Missing'] = df.shape[0] - summary['Missing']
    summary['Percent_Missing'] = summary['Missing']/df.shape[0]
    summary['Uniques'] = df.nunique().values
    summary['First Value'] = df.loc[0].values
    summary['Second Value'] = df.loc[1].values
    summary['Third Value'] = df.loc[2].values

    for name in summary['Name'].value_counts().index:
        summary.loc[summary['Name'] == name, 'Entropy'] = round(stats.entropy(df[name].value_counts(normalize=True), base=2),2) 

    return summary

# %%
data_raw=data_raw.reset_index().drop(['index'],axis=1)
pd.set_option('display.max_rows', 152)
resumetable(data_raw)
# Out:
# Dataset Shape: (324937, 151)
#                                            Name   dtypes  Missing  \
# 0                                            id   object        0
# 1                                     member_id  float64   324937
# 2                                     loan_amnt  float64        6
# 3                                   funded_amnt  float64        6
# 4                               funded_amnt_inv  float64        6
# 5                                          term   object        6
# 6                                      int_rate   object        6
# 7                                   installment  float64        6
# 8                                         grade   object        6
# 9                                     sub_grade   object        6
# 10                                    emp_title   object    22481
# 11                                   emp_length   object    22155
# 12                               home_ownership   object        6
# 13                                   annual_inc  float64        6
# 14                          verification_status   object        6
# 15                                      issue_d   object        6
# 16                                  loan_status   object        6
# 17                                   pymnt_plan   object        6
# 18                                          url   object        6
# 19                                         desc  float64   324937
# 20                                      purpose   object        6
# 21                                        title   object        6
# 22                                     zip_code   object        7
# 23                                   addr_state   object        6
# 24                                          dti  float64      298
# 25                                  delinq_2yrs  float64        6
# 26                             earliest_cr_line   object        6
# 27                               fico_range_low  float64        6
# 28                              fico_range_high  float64        6
# 29                               inq_last_6mths  float64        6
# 30                       mths_since_last_delinq  float64   157883
# 31                       mths_since_last_record  float64   266671
# 32                                     open_acc  float64        6
# 33                                      pub_rec  float64        6
# 34                                    revol_bal  float64        6
# 35                                   revol_util   object      259
# 36                                    total_acc  float64        6
# 37                          initial_list_status   object        6
# 38                                    out_prncp  float64        6
# 39                                out_prncp_inv  float64        6
# 40                                  total_pymnt  float64        6
# 41                              total_pymnt_inv  float64        6
# 42                              total_rec_prncp  float64        6
# 43                                total_rec_int  float64        6
# 44                           total_rec_late_fee  float64        6
# 45                                   recoveries  float64        6
# 46                      collection_recovery_fee  float64        6
# 47                                 last_pymnt_d   object      437
# 48                              last_pymnt_amnt  float64        6
# 49                                 next_pymnt_d   object    30618
# 50                           last_credit_pull_d   object       10
# 51                         last_fico_range_high  float64        6
# 52                          last_fico_range_low  float64        6
# 53                   collections_12_mths_ex_med  float64        6
# 54                  mths_since_last_major_derog  float64   235440
# 55                                  policy_code  float64        6
# 56                             application_type   object        6
# 57                             annual_inc_joint  float64   299723
# 58                                    dti_joint  float64   299723
# 59                    verification_status_joint   object   299723
# 60                               acc_now_delinq  float64        6
# 61                                 tot_coll_amt  float64        6
# 62                                  tot_cur_bal  float64        6
# 63                                  open_acc_6m  float64        6
# 64                                  open_act_il  float64        6
# 65                                  open_il_12m  float64        6
# 66                                  open_il_24m  float64        6
# 67                           mths_since_rcnt_il  float64     8791
# 68                                 total_bal_il  float64        6
# 69                                      il_util  float64    43192
# 70                                  open_rv_12m  float64        6
# 71                                  open_rv_24m  float64        6
# 72                                   max_bal_bc  float64        6
# 73                                     all_util  float64       36
# 74                             total_rev_hi_lim  float64        6
# 75                                       inq_fi  float64        6
# 76                                  total_cu_tl  float64        6
# 77                                 inq_last_12m  float64        6
# 78                         acc_open_past_24mths  float64        6
# 79                                  avg_cur_bal  float64       13
# 80                               bc_open_to_buy  float64     3870
# 81                                      bc_util  float64     4020
# 82                     chargeoff_within_12_mths  float64        6
# 83                                  delinq_amnt  float64        6
# 84                           mo_sin_old_il_acct  float64     8791
# 85                         mo_sin_old_rev_tl_op  float64        6
# 86                        mo_sin_rcnt_rev_tl_op  float64        6
# 87                               mo_sin_rcnt_tl  float64        6
# 88                                     mort_acc  float64        6
# 89                         mths_since_recent_bc  float64     3670
# 90                     mths_since_recent_bc_dlq  float64   246592
# 91                        mths_since_recent_inq  float64    37159
# 92               mths_since_recent_revol_delinq  float64   211147
# 93                        num_accts_ever_120_pd  float64        6
# 94                               num_actv_bc_tl  float64        6
# 95                              num_actv_rev_tl  float64        6
# 96                                  num_bc_sats  float64        6
# 97                                    num_bc_tl  float64        6
# 98                                    num_il_tl  float64        6
# 99                                num_op_rev_tl  float64        6
# 100                               num_rev_accts  float64        6
# 101                         num_rev_tl_bal_gt_0  float64        6
# 102                                    num_sats  float64        6
# 103                            num_tl_120dpd_2m  float64    15425
# 104                                num_tl_30dpd  float64        6
# 105                          num_tl_90g_dpd_24m  float64        6
# 106                          num_tl_op_past_12m  float64        6
# 107                              pct_tl_nvr_dlq  float64        6
# 108                            percent_bc_gt_75  float64     3877
# 109                        pub_rec_bankruptcies  float64        6
# 110                                   tax_liens  float64        6
# 111                             tot_hi_cred_lim  float64        6
# 112                           total_bal_ex_mort  float64        6
# 113                              total_bc_limit  float64        6
# 114                  total_il_high_credit_limit  float64        6
# 115                             revol_bal_joint  float64   303112
# 116                      sec_app_fico_range_low  float64   303112
# 117                     sec_app_fico_range_high  float64   303112
# 118                    sec_app_earliest_cr_line   object   303112
# 119                      sec_app_inq_last_6mths  float64   303112
# 120                            sec_app_mort_acc  float64   303112
# 121                            sec_app_open_acc  float64   303112
# 122                          sec_app_revol_util  float64   303400
# 123                         sec_app_open_act_il  float64   303112
# 124                       sec_app_num_rev_accts  float64   303112
# 125            sec_app_chargeoff_within_12_mths  float64   303112
# 126          sec_app_collections_12_mths_ex_med  float64   303112
# 127         sec_app_mths_since_last_major_derog  float64   317396
# 128                               hardship_flag   object        6
# 129                               hardship_type   object   324186
# 130                             hardship_reason   object   324186
# 131                             hardship_status   object   324186
# 132                               deferral_term  float64   324186
# 133                             hardship_amount  float64   324186
# 134                         hardship_start_date   object   324186
# 135                           hardship_end_date   object   324186
# 136                     payment_plan_start_date   object   324186
# 137                             hardship_length  float64   324186
# 138                                hardship_dpd  float64   324186
# 139                        hardship_loan_status   object   324186
# 140  orig_projected_additional_accrued_interest  float64   324257
# 141              hardship_payoff_balance_amount  float64   324186
# 142                hardship_last_payment_amount  float64   324186
# 143                         disbursement_method   object        6
# 144                        debt_settlement_flag   object        6
# 145                   debt_settlement_flag_date   object   324794
# 146                           settlement_status   object   324794
# 147                             settlement_date   object   324794
# 148                           settlement_amount  float64   324794
# 149                       settlement_percentage  float64   324794
# 150                             settlement_term  float64   324794
#
#      Non_Missing  Percent_Missing  Uniques  \
# 0         324937         0.000000   324937
# 1              0         1.000000        0
# 2         324931         0.000018     1549
# 3         324931         0.000018     1549
# 4         324931         0.000018     1551
# 5         324931         0.000018        2
# 6         324931         0.000018       65
# 7         324931         0.000018    30173
# 8         324931         0.000018        7
# 9         324931         0.000018       35
# 10        302456         0.069186    95032
# 11        302782         0.068182       11
# 12        324931         0.000018        5
# 13        324931         0.000018    22133
# 14        324931         0.000018        3
# 15        324931         0.000018        9
# 16        324931         0.000018        7
# 17        324931         0.000018        2
# 18        324931         0.000018   324931
# 19             0         1.000000        0
# 20        324931         0.000018       13
# 21        324931         0.000018       12
# 22        324930         0.000022      877
# 23        324931         0.000018       49
# 24        324639         0.000917     6972
# 25        324931         0.000018       26
# 26        324931         0.000018      666
# 27        324931         0.000018       38
# 28        324931         0.000018       38
# 29        324931         0.000018        6
# 30        167054         0.485888      140
# 31         58266         0.820685      121
# 32        324931         0.000018       76
# 33        324931         0.000018       24
# 34        324931         0.000018    55282
# 35        324678         0.000797     1140
# 36        324931         0.000018      122
# 37        324931         0.000018        2
# 38        324931         0.000018   107026
# 39        324931         0.000018   110973
# 40        324931         0.000018   155270
# 41        324931         0.000018   156855
# 42        324931         0.000018    98022
# 43        324931         0.000018   126156
# 44        324931         0.000018     1503
# 45        324931         0.000018      508
# 46        324931         0.000018      509
# 47        324500         0.001345       12
# 48        324931         0.000018    60616
# 49        294319         0.094227        3
# 50        324927         0.000031       13
# 51        324931         0.000018       72
# 52        324931         0.000018       71
# 53        324931         0.000018        8
# 54         89497         0.724571      162
# 55        324931         0.000018        1
# 56        324931         0.000018        2
# 57         25214         0.922403     5109
# 58         25214         0.922403     3378
# 59         25214         0.922403        3
# 60        324931         0.000018        5
# 61        324931         0.000018     6892
# 62        324931         0.000018   199027
# 63        324931         0.000018       16
# 64        324931         0.000018       47
# 65        324931         0.000018       12
# 66        324931         0.000018       22
# 67        316146         0.027054      322
# 68        324931         0.000018    98860
# 69        281745         0.132924      235
# 70        324931         0.000018       28
# 71        324931         0.000018       43
# 72        324931         0.000018    25082
# 73        324901         0.000111      170
# 74        324931         0.000018     8885
# 75        324931         0.000018       26
# 76        324931         0.000018       51
# 77        324931         0.000018       38
# 78        324931         0.000018       44
# 79        324924         0.000040    54280
# 80        321067         0.011910    52302
# 81        320917         0.012372     1222
# 82        324931         0.000018       10
# 83        324931         0.000018      896
# 84        316146         0.027054      490
# 85        324931         0.000018      707
# 86        324931         0.000018      252
# 87        324931         0.000018      166
# 88        324931         0.000018       29
# 89        321267         0.011294      420
# 90         78345         0.758892      145
# 91        287778         0.114358       26
# 92        113790         0.649809      150
# 93        324931         0.000018       40
# 94        324931         0.000018       33
# 95        324931         0.000018       49
# 96        324931         0.000018       47
# 97        324931         0.000018       64
# 98        324931         0.000018       98
# 99        324931         0.000018       69
# 100       324931         0.000018       96
# 101       324931         0.000018       43
# 102       324931         0.000018       73
# 103       309512         0.047471        5
# 104       324931         0.000018        4
# 105       324931         0.000018       26
# 106       324931         0.000018       27
# 107       324931         0.000018      578
# 108       321060         0.011932      182
# 109       324931         0.000018        8
# 110       324931         0.000018       26
# 111       324931         0.000018   202612
# 112       324931         0.000018   119362
# 113       324931         0.000018     4564
# 114       324931         0.000018   108249
# 115        21825         0.932833    18324
# 116        21825         0.932833       61
# 117        21825         0.932833       61
# 118        21825         0.932833      564
# 119        21825         0.932833        7
# 120        21825         0.932833       16
# 121        21825         0.932833       56
# 122        21537         0.933719     1097
# 123        21825         0.932833       34
# 124        21825         0.932833       72
# 125        21825         0.932833       13
# 126        21825         0.932833       11
# 127         7541         0.976792      116
# 128       324931         0.000018        2
# 129          751         0.997689        1
# 130          751         0.997689        9
# 131          751         0.997689        3
# 132          751         0.997689        1
# 133          751         0.997689      716
# 134          751         0.997689        5
# 135          751         0.997689        7
# 136          751         0.997689        6
# 137          751         0.997689        1
# 138          751         0.997689       27
# 139          751         0.997689        5
# 140          680         0.997907      648
# 141          751         0.997689      750
# 142          751         0.997689      600
# 143       324931         0.000018        2
# 144       324931         0.000018        2
# 145          143         0.999560        6
# 146          143         0.999560        3
# 147          143         0.999560        7
# 148          143         0.999560      143
# 149          143         0.999560       30
# 150          143         0.999560       14
#
#                                            First Value  \
# 0                                            104046719
# 1                                                  NaN
# 2                                                14000
# 3                                                14000
# 4                                                14000
# 5                                            36 months
# 6                                               15.99%
# 7                                               492.13
# 8                                                    C
# 9                                                   C5
# 10                                      Project Leader
# 11                                           10+ years
# 12                                            MORTGAGE
# 13                                               82000
# 14                                     Source Verified
# 15                                            Mar-2017
# 16                                             Current
# 17                                                   n
# 18   https://lendingclub.com/browse/loanDetail.acti...
# 19                                                 NaN
# 20                                         credit_card
# 21                             Credit card refinancing
# 22                                               672xx
# 23                                                  KS
# 24                                               31.07
# 25                                                   0
# 26                                            May-1996
# 27                                                 725
# 28                                                 729
# 29                                                   0
# 30                                                 NaN
# 31                                                 NaN
# 32                                                  18
# 33                                                   0
# 34                                               69578
# 35                                               63.2%
# 36                                                  31
# 37                                                   w
# 38                                             11438.3
# 39                                             11438.3
# 40                                             3912.17
# 41                                             3912.17
# 42                                             2561.74
# 43                                             1350.43
# 44                                                   0
# 45                                                   0
# 46                                                   0
# 47                                            Dec-2017
# 48                                              492.13
# 49                                            Jan-2018
# 50                                            Dec-2017
# 51                                                 714
# 52                                                 710
# 53                                                   0
# 54                                                 NaN
# 55                                                   1
# 56                                          Individual
# 57                                                 NaN
# 58                                                 NaN
# 59                                                 NaN
# 60                                                   0
# 61                                                   0
# 62                                              202617
# 63                                                   0
# 64                                                   3
# 65                                                   0
# 66                                                   1
# 67                                                  22
# 68                                               34430
# 69                                                  57
# 70                                                   0
# 71                                                   2
# 72                                               13686
# 73                                                  61
# 74                                              110037
# 75                                                   0
# 76                                                   9
# 77                                                   0
# 78                                                   3
# 79                                               11257
# 80                                               29762
# 81                                                63.4
# 82                                                   0
# 83                                                   0
# 84                                                 140
# 85                                                 250
# 86                                                  13
# 87                                                  13
# 88                                                   6
# 89                                                  13
# 90                                                 NaN
# 91                                                  13
# 92                                                 NaN
# 93                                                   0
# 94                                                   7
# 95                                                   9
# 96                                                   8
# 97                                                  13
# 98                                                   4
# 99                                                  14
# 100                                                 21
# 101                                                  9
# 102                                                 18
# 103                                                  0
# 104                                                  0
# 105                                                  0
# 106                                                  0
# 107                                                100
# 108                                                 25
# 109                                                  0
# 110                                                  0
# 111                                             286204
# 112                                             104008
# 113                                              81400
# 114                                              60167
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                  N
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                               Cash
# 144                                                  N
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
#
#                                           Second Value  \
# 0                                            104048967
# 1                                                  NaN
# 2                                                 5000
# 3                                                 5000
# 4                                                 5000
# 5                                            36 months
# 6                                               25.49%
# 7                                                200.1
# 8                                                    E
# 9                                                   E4
# 10                                               Pilot
# 11                                           10+ years
# 12                                            MORTGAGE
# 13                                              215000
# 14                                     Source Verified
# 15                                            Mar-2017
# 16                                             Current
# 17                                                   n
# 18   https://lendingclub.com/browse/loanDetail.acti...
# 19                                                 NaN
# 20                                  debt_consolidation
# 21                                  Debt consolidation
# 22                                               067xx
# 23                                                  CT
# 24                                                6.06
# 25                                                   0
# 26                                            Jan-2004
# 27                                                 765
# 28                                                 769
# 29                                                   4
# 30                                                 NaN
# 31                                                 NaN
# 32                                                  11
# 33                                                   0
# 34                                                8678
# 35                                               18.8%
# 36                                                  16
# 37                                                   f
# 38                                             4190.59
# 39                                             4190.59
# 40                                             1586.64
# 41                                             1586.64
# 42                                              809.41
# 43                                              777.23
# 44                                                   0
# 45                                                   0
# 46                                                   0
# 47                                            Dec-2017
# 48                                               200.1
# 49                                            Jan-2018
# 50                                            Dec-2017
# 51                                                 779
# 52                                                 775
# 53                                                   0
# 54                                                 NaN
# 55                                                   1
# 56                                          Individual
# 57                                                 NaN
# 58                                                 NaN
# 59                                                 NaN
# 60                                                   0
# 61                                                   0
# 62                                               44754
# 63                                                   1
# 64                                                   3
# 65                                                   2
# 66                                                   4
# 67                                                   7
# 68                                               35832
# 69                                                  68
# 70                                                   2
# 71                                                   2
# 72                                                8659
# 73                                                  27
# 74                                               46200
# 75                                                   2
# 76                                                   0
# 77                                                   6
# 78                                                   6
# 79                                                4069
# 80                                               37522
# 81                                                18.8
# 82                                                   0
# 83                                                   0
# 84                                                  83
# 85                                                  87
# 86                                                   5
# 87                                                   5
# 88                                                   0
# 89                                                   5
# 90                                                 NaN
# 91                                                   0
# 92                                                 NaN
# 93                                                   0
# 94                                                   2
# 95                                                   2
# 96                                                   7
# 97                                                   8
# 98                                                   7
# 99                                                   7
# 100                                                  8
# 101                                                  2
# 102                                                 11
# 103                                                  0
# 104                                                  0
# 105                                                  0
# 106                                                  4
# 107                                                100
# 108                                                  0
# 109                                                  0
# 110                                                  0
# 111                                             100763
# 112                                              44754
# 113                                              46200
# 114                                              49814
# 115                                                NaN
# 116                                                NaN
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
# 122                                                NaN
# 123                                                NaN
# 124                                                NaN
# 125                                                NaN
# 126                                                NaN
# 127                                                NaN
# 128                                                  N
# 129                                                NaN
# 130                                                NaN
# 131                                                NaN
# 132                                                NaN
# 133                                                NaN
# 134                                                NaN
# 135                                                NaN
# 136                                                NaN
# 137                                                NaN
# 138                                                NaN
# 139                                                NaN
# 140                                                NaN
# 141                                                NaN
# 142                                                NaN
# 143                                               Cash
# 144                                                  N
# 145                                                NaN
# 146                                                NaN
# 147                                                NaN
# 148                                                NaN
# 149                                                NaN
# 150                                                NaN
#
#                                            Third Value  Entropy
# 0                                            104028593    18.31
# 1                                                  NaN     0.00
# 2                                                 4600     6.58
# 3                                                 4600     6.58
# 4                                                 4600     6.73
# 5                                            36 months     0.84
# 6                                               11.39%     5.43
# 7                                               151.45    12.10
# 8                                                    B     2.21
# 9                                                   B3     4.51
# 10                                    cable technician    13.44
# 11                                             4 years     3.01
# 12                                                RENT     1.40
# 13                                               44470     8.19
# 14                                        Not Verified     1.57
# 15                                            Mar-2017     3.16
# 16                                             Current     0.72
# 17                                                   n     0.00
# 18   https://lendingclub.com/browse/loanDetail.acti...    18.31
# 19                                                 NaN     0.00
# 20                                         credit_card     2.03
# 21                             Credit card refinancing     2.03
# 22                                               066xx     8.90
# 23                                                  CT     4.85
# 24                                               13.43    11.76
# 25                                                   0     1.08
# 26                                            Dec-2003     8.40
# 27                                                 770     4.43
# 28                                                 774     4.43
# 29                                                   1     1.38
# 30                                                 NaN     6.28
# 31                                                 NaN     6.63
# 32                                                   7     4.40
# 33                                                   0     0.85
# 34                                                5400    15.09
# 35                                               19.1%     9.87
# 36                                                  11     5.48
# 37                                                   w     0.79
# 38                                              3708.5    14.23
# 39                                              3708.5    14.30
# 40                                             1205.78    16.23
# 41                                             1205.78    16.27
# 42                                               891.5    14.80
# 43                                              314.28    16.04
# 44                                                   0     0.18
# 45                                                   0     0.03
# 46                                                   0     0.03
# 47                                            Dec-2017     0.99
# 48                                              151.45    12.88
# 49                                            Jan-2018     0.00
# 50                                            Dec-2017     0.79
# 51                                                 769     5.22
# 52                                                 765     5.22
# 53                                                   0     0.16
# 54                                                 NaN     6.44
# 55                                                   1     0.00
# 56                                          Individual     0.39
# 57                                                 NaN     9.32
# 58                                                 NaN    11.39
# 59                                                 NaN     1.52
# 60                                                   0     0.05
# 61                                                   0     2.50
# 62                                                9625    17.35
# 63                                                   1     1.86
# 64                                                   1     3.02
# 65                                                   0     1.52
# 66                                                   1     2.36
# 67                                                  22     5.74
# 68                                                4225    15.01
# 69                                                  36     6.58
# 70                                                   2     2.24
# 71                                                   4     3.07
# 72                                                4670    13.65
# 73                                                  24     6.42
# 74                                               28300     9.96
# 75                                                   0     1.97
# 76                                                   0     2.29
# 77                                                   1     2.76
# 78                                                   5     3.53
# 79                                                1375    14.90
# 80                                                9610    14.57
# 81                                                33.7     9.92
# 82                                                   0     0.07
# 83                                                   0     0.09
# 84                                                  77     7.63
# 85                                                 159     8.51
# 86                                                   1     5.23
# 87                                                   1     4.46
# 88                                                   0     2.35
# 89                                                   7     5.97
# 90                                                 NaN     6.39
# 91                                                   1     4.28
# 92                                                 NaN     6.33
# 93                                                   0     1.32
# 94                                                   2     3.09
# 95                                                   3     3.59
# 96                                                   3     3.44
# 97                                                   4     4.00
# 98                                                   2     4.51
# 99                                                   6     4.07
# 100                                                  9     4.80
# 101                                                  3     3.56
# 102                                                  7     4.40
# 103                                                  0     0.01
# 104                                                  0     0.04
# 105                                                  0     0.40
# 106                                                  2     2.67
# 107                                                100     4.63
# 108                                                  0     3.76
# 109                                                  0     0.60
# 110                                                  0     0.30
# 111                                              40000    17.06
# 112                                               9625    16.52
# 113                                              14500     9.33
# 114                                              11700    14.70
# 115                                                NaN    14.07
# 116                                                NaN     5.11
# 117                                                NaN     5.11
# 118                                                NaN     8.32
# 119                                                NaN     1.60
# 120                                                NaN     2.47
# 121                                                NaN     4.58
# 122                                                NaN     9.80
# 123                                                NaN     3.12
# 124                                                NaN     4.83
# 125                                                NaN     0.21
# 126                                                NaN     0.39
# 127                                                NaN     6.40
# 128                                                  N     0.01
# 129                                                NaN     0.00
# 130                                                NaN     0.81
# 131                                                NaN     1.14
# 132                                                NaN     0.00
# 133                                                NaN     9.46
# 134                                                NaN     1.27
# 135                                                NaN     1.88
# 136                                                NaN     1.71
# 137                                                NaN     0.00
# 138                                                NaN     1.89
# 139                                                NaN     1.18
# 140                                                NaN     9.32
# 141                                                NaN     9.55
# 142                                                NaN     9.00
# 143                                               Cash     0.01
# 144                                                  N     0.01
# 145                                                NaN     2.19
# 146                                                NaN     0.25
# 147                                                NaN     2.33
# 148                                                NaN     7.16
# 149                                                NaN     3.36
# 150                                                NaN     2.72

# %%
NA_col = data_raw.isnull().sum()
NA_col = NA_col[NA_col.values >(0.3*len(data_raw))]
plt.figure(figsize=(20,4))
NA_col.plot(kind='bar')
plt.title('List of Columns & NA counts where NA values are more than 30%')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

total = len(data_raw)

plt.figure(figsize = (14,6))

g = sns.countplot(x="loan_status", data=data_raw, 
                  color='blue')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_xlabel("Loan Status Categories", fontsize=12)
g.set_ylabel("Count", fontsize=15)
g.set_title("Loan Status Types Distribution", fontsize=20)
sizes=[]
for p in g.patches:
    height = p.get_height()
    sizes.append(height)
    g.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g.set_ylim(0, max(sizes) * 1.10)

plt.show()

# From the figure and as explained by mam "Current is Non Risky and Rest are Risky"

# %%
def univariate(df,col,vartype,hue =None):
    
    '''
    Univariate function will plot the graphs based on the parameters.
    df      : dataframe name
    col     : Column name
    vartype : variable type : continuos or categorical
                Continuos(0)   : Distribution, Violin & Boxplot will be plotted.
                Categorical(1) : Countplot will be plotted.
    hue     : It's only applicable for categorical analysis.
    
    '''
    sns.set(style="darkgrid")
    
    if vartype == 0:
        fig, ax=plt.subplots(nrows =1,ncols=3,figsize=(20,8))
        ax[0].set_title("Distribution Plot")
        sns.distplot(df[col],ax=ax[0])
        ax[1].set_title("Violin Plot")
        sns.violinplot(data =df, x=col,ax=ax[1], inner="quartile")
        ax[2].set_title("Box Plot")
        sns.boxplot(data =df, x=col,ax=ax[2],orient='v')
    
    if vartype == 1:
        temp = pd.Series(data = hue)
        fig, ax = plt.subplots()
        width = len(df[col].unique()) + 6 + 4*len(temp.unique())
        fig.set_size_inches(width , 7)
        ax = sns.countplot(data = df, x= col, order=df[col].value_counts().index,hue = hue) 
        if len(temp.unique()) > 0:
            for p in ax.patches:
                ax.annotate('{:1.1f}%'.format((p.get_height()*100)/float(len(data_raw))), (p.get_x()+0.05, p.get_height()+20))  
        else:
            for p in ax.patches:
                ax.annotate(p.get_height(), (p.get_x()+0.32, p.get_height()+20)) 
        del temp
    else:
        exit
        
    plt.show()

# %%
#Loan Amount

univariate(df=data_raw.fillna(0),col='loan_amnt',vartype=0)

# %%
univariate(df=data_rawdata_raw.fillna(0),col='purpose',vartype=1,hue='loan_status')

# %%
# Not taking Non-Risky i.e current group
univariate(df=data_raw[data_raw['loan_status']!='Current'].fillna(0),col='purpose',vartype=1,hue='loan_status')

# %%
univariate(df=data_raw.fillna(0),col='home_ownership',vartype=1,hue='loan_status')

# %%
#Year Wise Loan
year_wise =data_raw.groupby(by= [data_raw.issue_d])[['loan_status']].count()
year_wise.rename(columns={"loan_status": "count"},inplace=True)
ax =year_wise.plot(figsize=(20,8))
year_wise.plot(kind='bar',figsize=(20,8),ax = ax)
plt.show()

# %%
univariate(df=data_raw.fillna(0),col='term',vartype=1,hue='loan_status')

# %%
df_loan = data_raw.loc[data_raw['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default'])]

# %%
#Loan Amount and Interest Rate distribution
df_loan['int_round'] = df_loan['int_rate'].apply(str.strip)

#I will start looking the loan_amnt column
plt.figure(figsize=(14,10))

# Loan Amt plot
plt.subplot(211)
g = sns.distplot(df_loan["loan_amnt"])
g.set_xlabel("Loan Amount Value", fontsize=16)
g.set_ylabel("Frequency", fontsize=16)
g.set_title("Loan Amount Distribuition", fontsize=20)

## Interest plot
plt.subplot(212)
g1 = sns.countplot(x="int_round", data=df_loan, 
                  color='blue')
g1.set_xlabel("Loan Interest Rate", fontsize=16)
g1.set_ylabel("Count", fontsize=16)
g1.set_title("Interest Rate Distribuition", fontsize=20)
sizes=[] # Get highest values in y
for p in g1.patches:
    height = p.get_height()
    sizes.append(height)
    g1.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g1.set_ylim(0, max(sizes) * 1.10) # set y limit based on highest heights

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()
# Out:
# /Users/mghosh2/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_loan['issue_month'], df_loan['issue_year'] = df_loan['issue_d'].str.split('-', 1).str

months_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
df_loan['issue_month'] = pd.Categorical(df_loan['issue_month'],
                                        categories=months_order, 
                                        ordered=True)
#Issue_d x loan_amount
plt.figure(figsize = (15,16))

plt.subplot(311)
g = sns.countplot(x='issue_month', hue='issue_year', 
                  data=df_loan[df_loan['issue_year'].astype(int) >= 2012])
#g.set_xticklabels(g.get_xticklabels(),rotation=90)
g.set_xlabel("Months of Year", fontsize=15)
g.set_ylabel("Count Loans", fontsize=15)
g.legend(loc='best')
g.set_title("Loan Amount by Months", fontsize=20)

plt.subplot(312)
#Looking the count of defaults though the issue_d that is The month which the loan was funded
g1 = sns.countplot(x='issue_year', hue='term', 
                   data=df_loan)
g1.set_xticklabels(g1.get_xticklabels(),rotation=90)
g1.set_xlabel("Years", fontsize=15)
g1.set_ylabel("Count Loans", fontsize=15)
g1.set_title("Total Loans by Years - With Term requested", fontsize=20)
sizes=[]
for p in g1.patches:
    height = p.get_height()
    sizes.append(height)
    g1.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g1.set_ylim(0, max(sizes) * 1.10)

plt.subplot(313)
#Looking the count of defaults though the issue_d that is The month which the loan was funded
g2 = sns.countplot(x='issue_year', data=df_loan.loc[(df_loan['loan_status'] == 'Charged Off') | 
                                                   (df_loan['loan_status'] == 'NMCP Charged Off') |
                                                   (df_loan['loan_status'] == 'Default')],
                  hue='term',)
g2.set_xticklabels(g.get_xticklabels(),rotation=90)
g2.set_xlabel("Dates", fontsize=15)
g2.set_ylabel("Count", fontsize=15)
g2.set_title("Analysing Charge Off and Default by Years", fontsize=20)
sizes=[]
for p in g2.patches:
    height = p.get_height()
    sizes.append(height)
    g2.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format(height/total*100),
            ha="center", fontsize=12) 
g2.set_ylim(0, max(sizes) * 1.10)

plt.subplots_adjust(hspace = 0.3,top = 0.9)

plt.show()
# Out:
# /Users/mghosh2/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/mghosh2/.local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#Purpose by loan status

#Exploring the loan_status x purpose
purp_loan= ['purpose', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
(round(pd.crosstab(df_loan[purp_loan[0]], df_loan[purp_loan[1]], 
                   normalize='columns') * 100,2)).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
#     #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow0_col0 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow0_col2 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow1_col0 {
#             background-color:  #a2daa2;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow1_col2 {
#             background-color:  #97d497;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow2_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow3_col0 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow3_col2 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow4_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow4_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow5_col0 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow5_col2 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow6_col0 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow6_col2 {
#             background-color:  #dffcdf;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow7_col0 {
#             background-color:  #e0fce0;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow7_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow7_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow8_col0 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow8_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow8_col2 {
#             background-color:  #c5edc5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow9_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow9_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow9_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow10_col0 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow10_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow10_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow11_col0 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow11_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_dfdacc72_4453_11ea_acbc_8c8590c9875arow11_col2 {
#             background-color:  #e1fde1;
#             color:  #000000;
#         }</style><table id="T_dfdacc72_4453_11ea_acbc_8c8590c9875a" ><thead>    <tr>        <th class="index_name level0" >loan_status</th>        <th class="col_heading level0 col0" >Charged Off</th>        <th class="col_heading level0 col1" >Default</th>        <th class="col_heading level0 col2" >Fully Paid</th>    </tr>    <tr>        <th class="index_name level0" >purpose</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dfdacc72_4453_11ea_acbc_8c8590c9875alevel0_row0" class="row_heading level0 row0" >car</th>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow0_col0" class="data row0 col0" >1.15</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow0_col1" class="data row0 col1" >0</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow0_col2" class="data row0 col2" >1.55</td>
#             </tr>
#             <tr>
#                         <th id="T_dfdacc72_4453_11ea_acbc_8c8590c9875alevel0_row1" class="row_heading level0 row1" >credit_card</th>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow1_col0" class="data row1 col0" >16.17</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow1_col1" class="data row1 col1" >33.33</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow1_col2" class="data row1 col2" >18.63</td>
#             </tr>
#             <tr>
#                         <th id="T_dfdacc72_4453_11ea_acbc_8c8590c9875alevel0_row2" class="row_heading level0 row2" >debt_consolidation</th>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow2_col0" class="data row2 col0" >54.81</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow2_col1" class="data row2 col1" >33.33</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow2_col2" class="data row2 col2" >54.08</td>
#             </tr>
#             <tr>
#                         <th id="T_dfdacc72_4453_11ea_acbc_8c8590c9875alevel0_row3" class="row_heading level0 row3" >home_improvement</th>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow3_col0" class="data row3 col0" >8.43</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow3_col1" class="data row3 col1" >0</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow3_col2" class="data row3 col2" >9.23</td>
#             </tr>
#             <tr>
#                         <th id="T_dfdacc72_4453_11ea_acbc_8c8590c9875alevel0_row4" class="row_heading level0 row4" >house</th>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow4_col0" class="data row4 col0" >0.46</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow4_col1" class="data row4 col1" >0</td>
#                         <td id="T_dfdacc72_4453_11ea_acbc_8c8590c9875arow4_col2" class="data row4 col2" >0.94</td>
#             </tr>
#             <tr>
#                         <th id="T_dfdacc72_4453_11ea_acbc_8c8590c9875alevel0_row5" class="row_heading

# %%
#Installment Distribution
plt.figure(figsize=(12,5))

sns.distplot(df_loan['installment'])
plt.title("Installment Distribution", fontsize=20)
plt.xlabel("Installment Range", fontsize=17)
plt.ylabel("Density", fontsize=17)

plt.show()

# %%
order_sub = df_loan.groupby("sub_grade")['int_rate'].count().index

plt.figure(figsize=(14,16))

plt.suptitle('Grade and Sub-Grade Distributions \n# Interest Rate and Loan Amount #', fontsize=22)

plt.subplot(311)
g = sns.boxplot(x="grade", y="loan_amnt", data=df_loan,
                palette="hls", hue="application_type", 
                order=["A",'B','C','D','E','F', 'G'])
g.set_xlabel("Grade Values", fontsize=17)
g.set_ylabel("Loan Amount", fontsize=17)
g.set_title("Lending Club Loan - Loan Amount Distribution by Grade", fontsize=20)
g.legend(loc='upper right')

plt.subplot(312)
g1 = sns.boxplot(x='grade', y="int_rate",data=df_loan, 
               hue="application_type", palette = "hls",  
               order=["A",'B','C','D','E','F', 'G'])
g1.set_xlabel("Grade Values", fontsize=17)
g1.set_ylabel("Interest Rate", fontsize=17)
g1.set_title("Lending Club Loan - Interest Rate Distribution by Grade", fontsize=20)

plt.subplot(313)
g2 = sns.boxenplot(x="sub_grade", y="int_rate", data=df_loan, 
                   palette="hls", order=order_sub)
g2.set_xlabel("Sub Grade Values", fontsize=15)
g2.set_ylabel("Interest Rate", fontsize=15)
g2.set_title("Lending Club Loan - Interest Rate Distribution by Sub-Grade", fontsize=20)

plt.subplots_adjust(hspace = 0.4,top = 0.9)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-07cc9a8fba78> in <module>
#      17 g1 = sns.boxplot(x='grade', y="int_rate",data=df_loan,
#      18                hue="application_type", palette = "hls",
# ---> 19                order=["A",'B','C','D','E','F', 'G'])
#      20 g1.set_xlabel("Grade Values", fontsize=17)
#      21 g1.set_ylabel("Interest Rate", fontsize=17)
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, notch, ax, **kwargs)
#    2229     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
#    2230                           orient, color, palette, saturation,
# -> 2231                           width, dodge, fliersize, linewidth)
#    2232
#    2233     if ax is None:
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth)
#     444                  width, dodge, fliersize, linewidth):
#     445
# --> 446         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     447         self.establish_colors(color, palette, saturation)
#     448
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     156
#     157             # Figure out the plotting orientation
# --> 158             orient = self.infer_orient(x, y, orient)
#     159
#     160             # Option 2a:
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in infer_orient(self, x, y, orient)
#     359         elif is_not_numeric(y):
#     360             if is_not_numeric(x):
# --> 361                 raise ValueError(no_numeric)
#     362             else:
#     363                 return "h"
#
# ValueError: Neither the `x` nor `y` variable appears to be numeric.

# %%
#Employment features
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import warnings
from collections import Counter

#First plot
trace0 = go.Bar(
    x = df_loan.emp_title.value_counts()[:40].index.values,
    y = df_loan.emp_title.value_counts()[:40].values,
    marker=dict(
        color=df_loan.emp_title.value_counts()[:40].values
    ),
)

data = [trace0]

layout = go.Layout(
    yaxis=dict(
        title='Count'
    ),
    xaxis=dict(
        title='Employment name'
    ),
    title='TOP 40 Employment Title'
)

fig = go.Figure(data=data, layout=layout)

py.iplot(fig, filename='emp-title-bar')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-58-490f8d6dbadf> in <module>
#       1 #Employment features
# ----> 2 import plotly.offline as py
#       3 py.init_notebook_mode(connected=True)
#       4 import plotly.graph_objs as go
#       5 import plotly.tools as tls
#
# ModuleNotFoundError: No module named 'plotly'
